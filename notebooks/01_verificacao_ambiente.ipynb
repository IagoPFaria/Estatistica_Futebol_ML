# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

print("Python:", sys.version)
print("Executável:", sys.executable)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Seaborn:", sns.__version__)
# Out:
# Python: 3.14.5 (tags/v3.14.5:5607950, May 10 2026, 10:43:50) [MSC v.1944 64 bit (AMD64)]
# Executável: c:\Users\iagop\Documents\Projetos\Estatistica_Futebol_ML\.venv\Scripts\python.exe
# Pandas: 3.0.5
# NumPy: 2.5.2
# Scikit-learn: 1.9.0
# Matplotlib: 3.11.1
# Seaborn: 0.13.2

# %%
import pandas as pd

dados = pd.DataFrame({
    "time": ["Atlético-MG", "Flamengo", "Palmeiras"],
    "gols": [2, 1, 0],
    "finalizacoes": [14, 10, 8]
})

dados
# Out:
#           time  gols  finalizacoes
# 0  Atlético-MG     2            14
# 1     Flamengo     1            10
# 2    Palmeiras     0             8
